# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('NSE MNC REVENUE 21-23.csv')

# %%
display(data)
# Out:
#     S.No.                                Company Name  \
# 0     1.0                                    3M India
# 1     2.0                                Abbott India
# 2     3.0                              Ambuja Cements
# 3     4.0                               Ashok Leyland
# 4     5.0                                        Bata
# 5     6.0                                       Bosch
# 6     7.0                                   Britannia
# 7     8.0                                     Castrol
# 8     9.0                                     Colgate
# 9    10.0                                     CRISIL
# 10   11.0                               Cummins India
# 11   12.0                                  GSK Pharma
# 12   13.0                        Honeywell Automation
# 13   14.0                          Hindustan Unilever
# 14   15.0                       Kansai Nerolac Paints
# 15   16.0                               Maruti Suzuki
# 16   17.0                                     MphasiS
# 17   18.0                            Oracle Financial
# 18   19.0  Procter and Gamble Hygiene and Health Care
# 19   20.0                                      Pfizer
# 20   21.0                                      Sanofi
# 21   22.0                                     Siemens
# 22   23.0                                   SKF India
# 23   24.0                       Sterlite Technologies
# 24   25.0                              United Spirits
# 25   26.0                               Vodafone Idea
# 26   27.0                          Whirlpool of India
# 27    NaN                                         NaN
# 28    NaN                                         NaN
# 29    NaN                                         NaN
# 30    NaN                                         NaN
#
#                           Email Address  Revenue for 2023 (in Rs. Cr.)  \
# 0                   vsrinivasan@mmm.com                        3797.66
# 1            krupa.anandpara@abbott.com                        5502.88
# 2               shares@ambujacement.com                       20937.70
# 3        ramanathan.n5@ashokleyland.com                       36260.28
# 4                 jamshed.alam@bata.com                        3488.92
# 5                 investor@in.bosch.com                       15402.70
# 6                 suhasmv@britindia.com                       15839.01
# 7                  chandana.dhar@bp.com                        5157.76
# 8              randhir_singh@colpal.com                        5279.77
# 9              minal.bhosale@crisil.com                            NaN
# 10            janhvie.khele@cummins.com                        8164.42
# 11               ajay.a.nadkani@gsk.com                        3317.86
# 12            farah.irani@honeywell.com                        3575.84
# 13              comsec.hul@unilever.com                       59784.00
# 14           gtgovindarajan@nerolac.com                        7111.85
# 15          sanjeev.grover@maruti.co.in                      119684.20
# 16      subramanian.narayan@mphasis.com                        9543.13
# 17  investors-vp-ofss_in_grp@oracle.com                        4508.22
# 18                   machado.f.1@pg.com                        3958.48
# 19              prajeet.nair@pfizer.com                        2525.81
# 20        Girish.Tekchandani@sanofi.com                            NaN
# 21             ketan.thaker@siemens.com                       18513.80
# 22             pradeep.bhandari@skf.com                        4356.79
# 23             secretarial@sterlite.com                        5531.00
# 24   Ramachandran.Venkatesan@diageo.com                       10447.90
# 25   investorrelations@vodafoneidea.com                       42187.80
# 26       investor_contact@whirlpool.com                        6332.28
# 27                                  NaN                            NaN
# 28                                  NaN                            NaN
# 29                                  NaN                            NaN
# 30                                  NaN                            NaN
#
#     Revenue for 2022 (in Rs. Cr.)  Revenue for  2021 (in Rs. Cr.)  \
# 0                         3113.02                         2447.23
# 1                         4996.48                         4390.92
# 2                        16532.99                        14250.59
# 3                        21764.42                        15420.95
# 4                         2443.62                         1801.33
# 5                        12177.90                        10222.00
# 6                        13731.05                        12671.53
# 7                         4841.54                         4240.49
# 8                         5126.04                         4871.57
# 9                         1716.95                         1544.33
# 10                        6427.90                         4699.39
# 11                        3293.72                         3030.66
# 12                        3030.66                         3126.75
# 13                       51586.00                        46509.00
# 14                        5981.76                         4728.71
# 15                       90089.10                        73278.90
# 16                        7512.77                         5650.71
# 17                        4152.15                         3761.69
# 18                        3925.24                         3613.52
# 19                        2673.64                         2319.67
# 20                        2841.60                         3031.00
# 21                       15147.60                        13182.10
# 22                        3700.29                         2706.96
# 23                        5080.49                         4199.68
# 24                        9423.20                         7937.00
# 25                       38318.20                        41931.10
# 26                        6055.02                         5989.49
# 27                            NaN                             NaN
# 28                            NaN                             NaN
# 29                            NaN                             NaN
# 30                            NaN                             NaN
#
#     Profitable\n(Yes/No)  Unnamed: 7  Unnamed: 8
# 0                    NaN         NaN         NaN
# 1                    NaN         NaN         NaN
# 2                    NaN         NaN         NaN
# 3                    NaN         NaN         NaN
# 4                    NaN         NaN         NaN
# 5                    NaN         NaN         NaN
# 6                    NaN         NaN         NaN
# 7                    NaN         NaN         NaN
# 8                    NaN         NaN         NaN
# 9                    NaN         NaN         NaN
# 10                   NaN         NaN         NaN
# 11                   NaN         NaN         NaN
# 12                   NaN         NaN         NaN
# 13                   NaN         NaN         NaN
# 14                   NaN         NaN         NaN
# 15                   NaN         NaN         NaN
# 16                   NaN         NaN         NaN
# 17                   NaN         NaN         NaN
# 18                   NaN         NaN         NaN
# 19                   NaN         NaN         NaN
# 20                   NaN         NaN         NaN
# 21                   NaN         NaN         NaN
# 22                   NaN         NaN         NaN
# 23                   NaN         NaN         NaN
# 24                   NaN         NaN         NaN
# 25                   NaN         NaN         NaN
# 26                   NaN         NaN         NaN
# 27                   NaN         NaN         NaN
# 28                   NaN         NaN         NaN
# 29                   NaN         NaN         NaN
# 30                   NaN         NaN         NaN

# %%
data.dropna(axis=1, how='all', inplace=True)
data.dropna(axis=0, how='all', inplace=True)
display(data)
# Out:
#     S.No.                                Company Name  \
# 0     1.0                                    3M India
# 1     2.0                                Abbott India
# 2     3.0                              Ambuja Cements
# 3     4.0                               Ashok Leyland
# 4     5.0                                        Bata
# 5     6.0                                       Bosch
# 6     7.0                                   Britannia
# 7     8.0                                     Castrol
# 8     9.0                                     Colgate
# 9    10.0                                     CRISIL
# 10   11.0                               Cummins India
# 11   12.0                                  GSK Pharma
# 12   13.0                        Honeywell Automation
# 13   14.0                          Hindustan Unilever
# 14   15.0                       Kansai Nerolac Paints
# 15   16.0                               Maruti Suzuki
# 16   17.0                                     MphasiS
# 17   18.0                            Oracle Financial
# 18   19.0  Procter and Gamble Hygiene and Health Care
# 19   20.0                                      Pfizer
# 20   21.0                                      Sanofi
# 21   22.0                                     Siemens
# 22   23.0                                   SKF India
# 23   24.0                       Sterlite Technologies
# 24   25.0                              United Spirits
# 25   26.0                               Vodafone Idea
# 26   27.0                          Whirlpool of India
#
#                           Email Address  Revenue for 2023 (in Rs. Cr.)  \
# 0                   vsrinivasan@mmm.com                        3797.66
# 1            krupa.anandpara@abbott.com                        5502.88
# 2               shares@ambujacement.com                       20937.70
# 3        ramanathan.n5@ashokleyland.com                       36260.28
# 4                 jamshed.alam@bata.com                        3488.92
# 5                 investor@in.bosch.com                       15402.70
# 6                 suhasmv@britindia.com                       15839.01
# 7                  chandana.dhar@bp.com                        5157.76
# 8              randhir_singh@colpal.com                        5279.77
# 9              minal.bhosale@crisil.com                            NaN
# 10            janhvie.khele@cummins.com                        8164.42
# 11               ajay.a.nadkani@gsk.com                        3317.86
# 12            farah.irani@honeywell.com                        3575.84
# 13              comsec.hul@unilever.com                       59784.00
# 14           gtgovindarajan@nerolac.com                        7111.85
# 15          sanjeev.grover@maruti.co.in                      119684.20
# 16      subramanian.narayan@mphasis.com                        9543.13
# 17  investors-vp-ofss_in_grp@oracle.com                        4508.22
# 18                   machado.f.1@pg.com                        3958.48
# 19              prajeet.nair@pfizer.com                        2525.81
# 20        Girish.Tekchandani@sanofi.com                            NaN
# 21             ketan.thaker@siemens.com                       18513.80
# 22             pradeep.bhandari@skf.com                        4356.79
# 23             secretarial@sterlite.com                        5531.00
# 24   Ramachandran.Venkatesan@diageo.com                       10447.90
# 25   investorrelations@vodafoneidea.com                       42187.80
# 26       investor_contact@whirlpool.com                        6332.28
#
#     Revenue for 2022 (in Rs. Cr.)  Revenue for  2021 (in Rs. Cr.)
# 0                         3113.02                         2447.23
# 1                         4996.48                         4390.92
# 2                        16532.99                        14250.59
# 3                        21764.42                        15420.95
# 4                         2443.62                         1801.33
# 5                        12177.90                        10222.00
# 6                        13731.05                        12671.53
# 7                         4841.54                         4240.49
# 8                         5126.04                         4871.57
# 9                         1716.95                         1544.33
# 10                        6427.90                         4699.39
# 11                        3293.72                         3030.66
# 12                        3030.66                         3126.75
# 13                       51586.00                        46509.00
# 14                        5981.76                         4728.71
# 15                       90089.10                        73278.90
# 16                        7512.77                         5650.71
# 17                        4152.15                         3761.69
# 18                        3925.24                         3613.52
# 19                        2673.64                         2319.67
# 20                        2841.60                         3031.00
# 21                       15147.60                        13182.10
# 22                        3700.29                         2706.96
# 23                        5080.49                         4199.68
# 24                        9423.20                         7937.00
# 25                       38318.20                        41931.10
# 26                        6055.02                         5989.49

# %%
print("Missing Values:")
print(data.isnull().sum())
# Out:
# Missing Values:
# S.No.                             0
# Company Name                      0
# Email Address                     0
# Revenue for 2023 (in Rs. Cr.)     2
# Revenue for 2022 (in Rs. Cr.)     0
# Revenue for  2021 (in Rs. Cr.)    0
# dtype: int64

# %%
data.columns = ['S.No.', 'Company Name', 'Company Email', 'FY23', 'FY22', 'FY21']
data.drop('Company Email', axis=1, inplace=True)
data.drop('S.No', axis=1, inplace=True)
display(data)
# Out:
#                                   Company Name       FY23      FY22      FY21
# 0                                     3M India    3797.66   3113.02   2447.23
# 1                                 Abbott India    5502.88   4996.48   4390.92
# 2                               Ambuja Cements   20937.70  16532.99  14250.59
# 3                                Ashok Leyland   36260.28  21764.42  15420.95
# 4                                         Bata    3488.92   2443.62   1801.33
# 5                                        Bosch   15402.70  12177.90  10222.00
# 6                                    Britannia   15839.01  13731.05  12671.53
# 7                                      Castrol    5157.76   4841.54   4240.49
# 8                                      Colgate    5279.77   5126.04   4871.57
# 9                                      CRISIL         NaN   1716.95   1544.33
# 10                               Cummins India    8164.42   6427.90   4699.39
# 11                                  GSK Pharma    3317.86   3293.72   3030.66
# 12                        Honeywell Automation    3575.84   3030.66   3126.75
# 13                          Hindustan Unilever   59784.00  51586.00  46509.00
# 14                       Kansai Nerolac Paints    7111.85   5981.76   4728.71
# 15                               Maruti Suzuki  119684.20  90089.10  73278.90
# 16                                     MphasiS    9543.13   7512.77   5650.71
# 17                            Oracle Financial    4508.22   4152.15   3761.69
# 18  Procter and Gamble Hygiene and Health Care    3958.48   3925.24   3613.52
# 19                                      Pfizer    2525.81   2673.64   2319.67
# 20                                      Sanofi        NaN   2841.60   3031.00
# 21                                     Siemens   18513.80  15147.60  13182.10
# 22                                   SKF India    4356.79   3700.29   2706.96
# 23                       Sterlite Technologies    5531.00   5080.49   4199.68
# 24                              United Spirits   10447.90   9423.20   7937.00
# 25                               Vodafone Idea   42187.80  38318.20  41931.10
# 26                          Whirlpool of India    6332.28   6055.02   5989.49

# %%
data['Company Name'] = data['Company Name'].astype(str)

# %%
revenue_cols = ['FY21', 'FY22', 'FY23']

non_numeric_values = {}
for col in revenue_cols:
    non_numeric_rows = data[pd.to_numeric(data[col], errors='coerce').isnull()]
    if not non_numeric_rows.empty:
        non_numeric_values[col] = non_numeric_rows[col].unique()

# %%
if non_numeric_values:
    print("\nNon-numeric values in revenue columns:")
    for col, values in non_numeric_values.items():
        print(f"Column '{col}': {values}")
# Out:
# Non-numeric values in revenue columns:
# Column 'FY23': [nan]

# %%
data['FY21_FY22_Change'] = data['FY22'] - data['FY21']
data['FY22_FY23_Change'] = data['FY23'] - data['FY22']

# %%
data[revenue_cols] = data[revenue_cols].apply(pd.to_numeric, errors='coerce')

# %%
data['FY21_FY22_Change'] = data['FY22'] - data['FY21']
data['FY22_FY23_Change'] = data['FY23'] - data['FY22']

# %%
print("\nYear-to-Year Changes:")
display(data[['Company Name', 'FY21_FY22_Change', 'FY22_FY23_Change']])
# Out:
# Year-to-Year Changes:
#                                   Company Name  FY21_FY22_Change  \
# 0                                     3M India            665.79
# 1                                 Abbott India            605.56
# 2                               Ambuja Cements           2282.40
# 3                                Ashok Leyland           6343.47
# 4                                         Bata            642.29
# 5                                        Bosch           1955.90
# 6                                    Britannia           1059.52
# 7                                      Castrol            601.05
# 8                                      Colgate            254.47
# 9                                      CRISIL             172.62
# 10                               Cummins India           1728.51
# 11                                  GSK Pharma            263.06
# 12                        Honeywell Automation            -96.09
# 13                          Hindustan Unilever           5077.00
# 14                       Kansai Nerolac Paints           1253.05
# 15                               Maruti Suzuki          16810.20
# 16                                     MphasiS           1862.06
# 17                            Oracle Financial            390.46
# 18  Procter and Gamble Hygiene and Health Care            311.72
# 19                                      Pfizer            353.97
# 20                                      Sanofi           -189.40
# 21                                     Siemens           1965.50
# 22                                   SKF India            993.33
# 23                       Sterlite Technologies            880.81
# 24                              United Spirits           1486.20
# 25                               Vodafone Idea          -3612.90
# 26                          Whirlpool of India             65.53
#
#     FY22_FY23_Change
# 0             684.64
# 1             506.40
# 2            4404.71
# 3           14495.86
# 4            1045.30
# 5            3224.80
# 6            2107.96
# 7             316.22
# 8             153.73
# 9                NaN
# 10           1736.52
# 11             24.14
# 12            545.18
# 13           8198.00
# 14           1130.09
# 15          29595.10
# 16           2030.36
# 17            356.07
# 18             33.24
# 19           -147.83
# 20               NaN
# 21           3366.20
# 22            656.50
# 23            450.51
# 24           1024.70
# 25           3869.60
# 26            277.26

# %%
data['Profitable'] = (data['FY23'] > data['FY21'])

plt.figure(figsize=(8, 6))
plt.scatter(data['FY21_FY22_Change'], data['FY22_FY23_Change'])
plt.xlabel('FY21 to FY22 Change')
plt.ylabel('FY22 to FY23 Change')
plt.title('Year-to-Year Comparison: FY21 to FY22 vs. FY22 to FY23')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.scatter(data['FY22_FY23_Change'], data['FY21_FY22_Change'])
plt.xlabel('FY22 to FY23 Change')
plt.ylabel('FY21 to FY22 Change')
plt.title('Year-to-Year Comparison: FY22 to FY23 vs. FY21 to FY22')
plt.grid(True)
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.bar(data.index, data['FY21'], color='purple', alpha=0.5, label='FY21')
plt.bar(data.index, data['FY22'], color='yellow', alpha=0.5, label='FY23')
plt.xlabel('Company Index')
plt.ylabel('Revenue')
plt.title('Comparison of Revenues in FY21 and FY23')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.bar(data.index, data['FY22'], color='purple', alpha=0.5, label='FY21')
plt.bar(data.index, data['FY23'], color='yellow', alpha=0.5, label='FY23')
plt.xlabel('Company Index')
plt.ylabel('Revenue')
plt.title('Comparison of Revenues in FY21 and FY23')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(8, 6))
plt.bar(data.index, data['FY21'], color='blue', alpha=0.5, label='FY21')
plt.bar(data.index, data['FY23'], color='red', alpha=0.5, label='FY23')
plt.xlabel('Company Index')
plt.ylabel('Revenue')
plt.title('Comparison of Revenues in FY21 and FY23')
plt.legend()
plt.show()

# %%
# 1. Positive Changes
positive_changes = data[(data['FY21_FY22_Change'] > 0) & (data['FY22_FY23_Change'] > 0)]

# 2. Negative Changes
negative_changes = data[(data['FY21_FY22_Change'] < 0) | (data['FY22_FY23_Change'] < 0)]

# 3. Missing Values
missing_values = data[data.isnull().any(axis=1)]

print("Positive Changes:")
display(positive_changes)
print("\nNegative Changes:")
display(negative_changes)
print("\nMissing Values:")
display(missing_values)
# Out:
# Positive Changes:
#                                   Company Name       FY23      FY22      FY21  \
# 0                                     3M India    3797.66   3113.02   2447.23
# 1                                 Abbott India    5502.88   4996.48   4390.92
# 2                               Ambuja Cements   20937.70  16532.99  14250.59
# 3                                Ashok Leyland   36260.28  21764.42  15420.95
# 4                                         Bata    3488.92   2443.62   1801.33
# 5                                        Bosch   15402.70  12177.90  10222.00
# 6                                    Britannia   15839.01  13731.05  12671.53
# 7                                      Castrol    5157.76   4841.54   4240.49
# 8                                      Colgate    5279.77   5126.04   4871.57
# 10                               Cummins India    8164.42   6427.90   4699.39
# 11                                  GSK Pharma    3317.86   3293.72   3030.66
# 13                          Hindustan Unilever   59784.00  51586.00  46509.00
# 14                       Kansai Nerolac Paints    7111.85   5981.76   4728.71
# 15                               Maruti Suzuki  119684.20  90089.10  73278.90
# 16                                     MphasiS    9543.13   7512.77   5650.71
# 17                            Oracle Financial    4508.22   4152.15   3761.69
# 18  Procter and Gamble Hygiene and Health Care    3958.48   3925.24   3613.52
# 21                                     Siemens   18513.80  15147.60  13182.10
# 22                                   SKF India    4356.79   3700.29   2706.96
# 23                       Sterlite Technologies    5531.00   5080.49   4199.68
# 24                              United Spirits   10447.90   9423.20   7937.00
# 26                          Whirlpool of India    6332.28   6055.02   5989.49
#
#     FY21_FY22_Change  FY22_FY23_Change  Profitable
# 0             665.79            684.64        True
# 1             605.56            506.40        True
# 2            2282.40           4404.71        True
# 3            6343.47          14495.86        True
# 4             642.29           1045.30        True
# 5            1955.90           3224.80        True
# 6            1059.52           2107.96        True
# 7             601.05            316.22        True
# 8             254.47            153.73        True
# 10           1728.51           1736.52        True
# 11            263.06             24.14        True
# 13           5077.00           8198.00        True
# 14           1253.05           1130.09        True
# 15          16810.20          29595.10        True
# 16           1862.06           2030.36        True
# 17            390.46            356.07        True
# 18            311.72             33.24        True
# 21           1965.50           3366.20        True
# 22            993.33            656.50        True
# 23            880.81            450.51        True
# 24           1486.20           1024.70        True
# 26             65.53            277.26        True
# Negative Changes:
#             Company Name      FY23      FY22      FY21  FY21_FY22_Change  \
# 12  Honeywell Automation   3575.84   3030.66   3126.75            -96.09
# 19                Pfizer   2525.81   2673.64   2319.67            353.97
# 20                Sanofi       NaN   2841.60   3031.00           -189.40
# 25         Vodafone Idea  42187.80  38318.20  41931.10          -3612.90
#
#     FY22_FY23_Change  Profitable
# 12            545.18        True
# 19           -147.83        True
# 20               NaN       False
# 25           3869.60        True
# Missing Values:
#    Company Name  FY23     FY22     FY21  FY21_FY22_Change  FY22_FY23_Change  \
# 9       CRISIL    NaN  1716.95  1544.33            172.62               NaN
# 20       Sanofi   NaN  2841.60  3031.00           -189.40               NaN
#
#     Profitable
# 9        False
# 20       False

# %%
data['% Change FY21-FY22'] = ((data['FY22'] - data['FY21']) / data['FY21']) * 100
data['% Change FY22-FY23'] = ((data['FY23'] - data['FY22']) / data['FY22']) * 100
print("Data with Percentage Change in Revenue:")
display(data[['Company Name','FY21_FY22_Change', '% Change FY21-FY22', 'FY22_FY23_Change', '% Change FY22-FY23']])
# Out:
# Data with Percentage Change in Revenue:
#                                   Company Name  FY21_FY22_Change  \
# 0                                     3M India            665.79
# 1                                 Abbott India            605.56
# 2                               Ambuja Cements           2282.40
# 3                                Ashok Leyland           6343.47
# 4                                         Bata            642.29
# 5                                        Bosch           1955.90
# 6                                    Britannia           1059.52
# 7                                      Castrol            601.05
# 8                                      Colgate            254.47
# 9                                      CRISIL             172.62
# 10                               Cummins India           1728.51
# 11                                  GSK Pharma            263.06
# 12                        Honeywell Automation            -96.09
# 13                          Hindustan Unilever           5077.00
# 14                       Kansai Nerolac Paints           1253.05
# 15                               Maruti Suzuki          16810.20
# 16                                     MphasiS           1862.06
# 17                            Oracle Financial            390.46
# 18  Procter and Gamble Hygiene and Health Care            311.72
# 19                                      Pfizer            353.97
# 20                                      Sanofi           -189.40
# 21                                     Siemens           1965.50
# 22                                   SKF India            993.33
# 23                       Sterlite Technologies            880.81
# 24                              United Spirits           1486.20
# 25                               Vodafone Idea          -3612.90
# 26                          Whirlpool of India             65.53
#
#     % Change FY21-FY22  FY22_FY23_Change  % Change FY22-FY23
# 0            27.205861            684.64           21.992792
# 1            13.791187            506.40           10.135135
# 2            16.016179           4404.71           26.641944
# 3            41.135403          14495.86           66.603475
# 4            35.656432           1045.30           42.776700
# 5            19.134220           3224.80           26.480756
# 6             8.361421           2107.96           15.351776
# 7            14.174070            316.22            6.531393
# 8             5.223573            153.73            2.999001
# 9            11.177663               NaN                 NaN
# 10           36.781582           1736.52           27.015355
# 11            8.679958             24.14            0.732910
# 12           -3.073159            545.18           17.988821
# 13           10.916167           8198.00           15.891909
# 14           26.498770           1130.09           18.892266
# 15           22.940028          29595.10           32.850922
# 16           32.952673           2030.36           27.025451
# 17           10.379909            356.07            8.575557
# 18            8.626492             33.24            0.846827
# 19           15.259498           -147.83           -5.529166
# 20           -6.248763               NaN                 NaN
# 21           14.910371           3366.20           22.222662
# 22           36.695407            656.50           17.741853
# 23           20.973265            450.51            8.867452
# 24           18.724959           1024.70           10.874225
# 25           -8.616278           3869.60           10.098595
# 26            1.094083            277.26            4.579010

# %%
plt.figure(figsize=(10, 6))

plt.bar(data['Company Name'], data['% Change FY21-FY22'], color='blue', alpha=0.5, label='% Change FY21-FY22')
plt.bar(data['Company Name'], data['% Change FY22-FY23'], color='red', alpha=0.5, label='% Change FY22-FY23')

plt.xlabel('Company')
plt.ylabel('% Change in Revenue')
plt.title('Percentage Change in Revenue for Each Company')
plt.xticks(rotation=90)
plt.legend()
plt.tight_layout()

plt.show()

# %%
print("\nCompanies with Best Change in Revenue Amount (FY21-FY22):")
best_change_21_22 = data.nlargest(5, 'FY21_FY22_Change')
display(best_change_21_22[['Company Name', 'FY21_FY22_Change']])

print("\nCompanies with Worst Change in Revenue Amount (FY21-FY22):")
worst_change_21_22 = data.nsmallest(5, 'FY21_FY22_Change')
display(worst_change_21_22[['Company Name', 'FY21_FY22_Change']])

print("\nCompanies with Best Change in Revenue Amount (FY22-FY23):")
best_change_22_23 = data.nlargest(5, 'FY22_FY23_Change')
display(best_change_22_23[['Company Name', 'FY22_FY23_Change']])

print("\nCompanies with Worst Change in Revenue Amount (FY22-FY23):")
worst_change_22_23 = data.nsmallest(5, 'FY22_FY23_Change')
display(worst_change_22_23[['Company Name', 'FY22_FY23_Change']])
# Out:
# Companies with Best Change in Revenue Amount (FY21-FY22):
#           Company Name  FY21_FY22_Change
# 15       Maruti Suzuki          16810.20
# 3        Ashok Leyland           6343.47
# 13  Hindustan Unilever           5077.00
# 2       Ambuja Cements           2282.40
# 21             Siemens           1965.50
# Companies with Worst Change in Revenue Amount (FY21-FY22):
#             Company Name  FY21_FY22_Change
# 25         Vodafone Idea          -3612.90
# 20                Sanofi           -189.40
# 12  Honeywell Automation            -96.09
# 26    Whirlpool of India             65.53
# 9                CRISIL             172.62
# Companies with Best Change in Revenue Amount (FY22-FY23):
#           Company Name  FY22_FY23_Change
# 15       Maruti Suzuki          29595.10
# 3        Ashok Leyland          14495.86
# 13  Hindustan Unilever           8198.00
# 2       Ambuja Cements           4404.71
# 25       Vodafone Idea           3869.60
# Companies with Worst Change in Revenue Amount (FY22-FY23):
#                                   Company Name  FY22_FY23_Change
# 19                                      Pfizer           -147.83
# 11                                  GSK Pharma             24.14
# 18  Procter and Gamble Hygiene and Health Care             33.24
# 8                                      Colgate            153.73
# 26                          Whirlpool of India            277.26

# %%
print("\nCompanies with Best Change in Revenue % (FY21-FY22):")
best_change_21_22 = data.nlargest(5, '% Change FY21-FY22')
display(best_change_21_22[['Company Name', '% Change FY21-FY22']])

print("\nCompanies with Worst Change in Revenue % (FY21-FY22):")
worst_change_21_22 = data.nsmallest(5, '% Change FY21-FY22')
display(worst_change_21_22[['Company Name', '% Change FY21-FY22']])

print("\nCompanies with Best Change in Revenue % (FY22-FY23):")
best_change_22_23 = data.nlargest(5, '% Change FY22-FY23')
display(best_change_22_23[['Company Name', '% Change FY22-FY23']])

print("\nCompanies with Worst Change in Revenue % (FY22-FY23):")
worst_change_22_23 = data.nsmallest(5, '% Change FY22-FY23')
display(worst_change_22_23[['Company Name', '% Change FY22-FY23']])
# Out:
# Companies with Best Change in Revenue % (FY21-FY22):
#      Company Name  % Change FY21-FY22
# 3   Ashok Leyland           41.135403
# 10  Cummins India           36.781582
# 22      SKF India           36.695407
# 4            Bata           35.656432
# 16        MphasiS           32.952673
# Companies with Worst Change in Revenue % (FY21-FY22):
#             Company Name  % Change FY21-FY22
# 25         Vodafone Idea           -8.616278
# 20                Sanofi           -6.248763
# 12  Honeywell Automation           -3.073159
# 26    Whirlpool of India            1.094083
# 8                Colgate            5.223573
# Companies with Best Change in Revenue % (FY22-FY23):
#      Company Name  % Change FY22-FY23
# 3   Ashok Leyland           66.603475
# 4            Bata           42.776700
# 15  Maruti Suzuki           32.850922
# 16        MphasiS           27.025451
# 10  Cummins India           27.015355
# Companies with Worst Change in Revenue % (FY22-FY23):
#                                   Company Name  % Change FY22-FY23
# 19                                      Pfizer           -5.529166
# 11                                  GSK Pharma            0.732910
# 18  Procter and Gamble Hygiene and Health Care            0.846827
# 8                                      Colgate            2.999001
# 26                          Whirlpool of India            4.579010

# %%
plt.figure(figsize=(10, 6))

for j, row in data.iterrows():
    height = row['% Change FY21-FY22']
    plt.bar(j, height, color='blue', alpha=0.5)
    plt.text(j, 0, f"{height:.1f}%", ha='center', va='bottom', rotation=90)

plt.xticks(range(len(data['Company Name'])), data['Company Name'], rotation=90)
plt.xlabel('Company')
plt.ylabel('% Change in Revenue')
plt.title('Percentage Change in Revenue (FY21-FY22)')
plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(10, 6))

for j, row in data.iterrows():
    height = row['% Change FY22-FY23']
    plt.bar(j, height, color='red', alpha=0.5)
    plt.text(j, 0, f"{height:.2f}%", ha='center', va='bottom', rotation=90)

plt.xticks(range(len(data['Company Name'])), data['Company Name'], rotation=90)
plt.xlabel('Company')
plt.ylabel('% Change in Revenue')
plt.title('Proportional Area Graph for Percentage Change in Revenue (FY22-FY23)')
plt.tight_layout()
plt.show()
